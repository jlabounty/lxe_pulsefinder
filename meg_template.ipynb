# %%
import numpy as np
import os 
import sys
import numba 
import matplotlib.pyplot as plt
import iminuit 
import scipy
import pandas

from template_fit import *

# %%
# Data stolen from Figure 4.12 of 

df = pandas.read_csv("./meg_template.csv", header=None)
df[0] = df[0]*10**3
df[1] = df[1] * -1
df.head()
# Out:
#            0         1
# 0 -67.922850 -0.015292
# 1 -66.330378 -0.014588
# 2 -64.737906 -0.013884
# 3 -63.145434 -0.013181
# 4 -61.552962 -0.012477

# %%
plt.plot(df[0], df[1])

# %%
template = LXeTemplate()
template.form_template(df[0].to_numpy(), df[1].to_numpy())
template.save("meg.template")

# %%
xs = np.linspace(-100,400,1000)
ys = template.template(xs)

fig,ax = plt.subplots(figsize=(15,5))
plt.plot(xs,ys)
